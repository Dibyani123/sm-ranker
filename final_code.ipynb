# %%
#IMPORTING LIBRARIES

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

#REMOVING ALL WARNING MESSAGES
import warnings
warnings.filterwarnings("ignore")

# %%
#IMPORTING THE TRAINING DATASET
df = pd.read_excel('DataDashTrainingData.xlsx')

# %%
df.head()
# Out:
#          name       date                                             tweets  \
# 0  company_46 2021-10-23  [{'text': '.@PM360online calls the work of our...
# 1  company_17 2021-10-23  [{'text': '@Amyrive21803741 Yikes! Sorry to he...
# 2  company_91 2021-10-23  [{'text': 'Hellmannâ€™s x AE collab. Dropping ...
# 3   company_2 2021-10-23  [{'text': '@Charli3BiNks ðŸ‘ ðŸ‘ ðŸ‘ Ok, we...
# 4  company_38 2021-10-23                                                 []
#
#    count_tweets  avg_tweet_likes  avg_tweet_retweets chatter  followers  \
# 0           2.0         2.000000               1.000     NaN      72753
# 1           3.0         0.000000               0.000     NaN     501445
# 2          10.0       122.800000               3.100     NaN     571479
# 3           7.0         0.714286               0.000     NaN      60221
# 4         240.0         0.741667               0.075     NaN     383493
#
#    following    change  rank  rank on the following day (dpv1)  \
# 0        496  0.000110  32.0                              29.0
# 1         65 -0.000088  91.0                              81.0
# 2       2999  0.000002  68.0                              61.0
# 3        766  0.000017  57.0                              52.0
# 4       6181  0.000034  54.0                              45.0
#
#    rank 2 days later            ( dpv2)  rank 3 days later          (dpv3)
# 0                                  25.0                               31.0
# 1                                  83.0                               84.0
# 2                                  86.0                               92.0
# 3                                  55.0                               51.0
# 4                                  35.0                               65.0

# %%
len(df)
# Out:
# 1209

# %% [markdown]
# # FEATURE ENGINEERING

# %%
df.describe()
# Out:
#        count_tweets  avg_tweet_likes  avg_tweet_retweets     followers  \
# count   1007.000000      1209.000000         1209.000000  1.209000e+03
# mean      13.527309        39.418935            8.591025  1.122702e+06
# std       37.190619       387.018589           82.324540  2.984283e+06
# min        1.000000         0.000000            0.000000  5.110700e+04
# 25%        2.000000         0.000000            0.000000  1.094500e+05
# 50%        5.000000         1.000000            0.166667  3.250900e+05
# 75%       17.500000         8.000000            2.000000  7.733170e+05
# max      520.000000     11462.375000         2166.375000  2.389704e+07
#
#            following       change         rank  \
# count    1209.000000  1209.000000  1209.000000
# mean     8081.205128     0.000115    47.000000
# std     17708.493189     0.000305    26.855589
# min         4.000000    -0.000357     1.000000
# 25%       337.000000     0.000000    24.000000
# 50%      1397.000000     0.000064    47.000000
# 75%      5489.000000     0.000157    70.500000
# max    105215.000000     0.007013    93.000000
#
#        rank on the following day (dpv1)  rank 2 days later            ( dpv2)  \
# count                       1209.000000                           1209.000000
# mean                          47.000000                             47.000000
# std                           26.855828                             26.855836
# min                            1.000000                              1.000000
# 25%                           24.000000                             24.000000
# 50%                           47.000000                             47.000000
# 75%                           70.000000                             70.000000
# max                           93.000000                             93.000000
#
#        rank 3 days later          (dpv3)
# count                        1209.000000
# mean                           47.000000
# std                            26.855836
# min                             1.000000
# 25%                            24.000000
# 50%                            47.000000
# 75%                            70.000000
# max                            93.000000

# %%
#COUNT OF NULL VALUES
df.isnull().sum()
# Out:
# name                                      0
# date                                      0
# tweets                                    0
# count_tweets                            202
# avg_tweet_likes                           0
# avg_tweet_retweets                        0
# chatter                                 558
# followers                                 0
# following                                 0
# change                                    0
# rank                                      0
# rank on the following day (dpv1)          0
# rank 2 days later            ( dpv2)      0
# rank 3 days later          (dpv3)         0
# dtype: int64

# %%
#GETTING THE COLUMNS WITH NULL VALUES
sns.heatmap(df.isnull(),yticklabels= False,cbar =False,cmap ='viridis')

# %%
df.name.value_counts()
# Out:
# company_75    13
# company_71    13
# company_84    13
# company_60    13
# company_37    13
#               ..
# company_91    13
# company_88    13
# company_67    13
# company_42    13
# company_81    13
# Name: name, Length: 93, dtype: int64

# %%
#IMPORTING THE TEST DATASET
df_pred = pd.read_csv('testing_data.csv')

# %%
df_pred.head()
# Out:
#    ID                                             tweets  count_tweets  \
# 0   1  [{'text': 'JUST IN: Weâ€™re sharing #BloodCanc...           2.0
# 1   2  [{'text': '@Sadu_SBS DM us your order # &amp; ...           3.0
# 2   3  [{'text': 'Lifeâ€™s too short to wear uncomfor...          10.0
# 3   4  [{'text': '@emma_lynne03 We just have one ques...           4.0
# 4   5  [{'text': "@NYYash Unfortunately flight 790 ha...          20.0
#
#    avg_tweet_likes  avg_tweet_retweets  \
# 0        10.000000                 0.5
# 1         0.333333                 0.0
# 2        24.500000                 2.3
# 3         0.250000                 0.0
# 4         0.300000                 0.0
#
#                                              chatter  followers  following  \
# 0  [{'text': 'RT @SligoLGFA: Sligo LGFA countdown...      72930        496
# 1  [{'text': '@Abercrombie I bought a fewT-shirtâ...     501153         65
# 2  [{'text': '@AEO I re designed your logo for fu...     571362       1290
# 3  [{'text': '@MurrayLinus @BelfastHome @tinamcke...      60224        767
# 4  [{'text': 'RT @BeciMahnken: Trams going to gat...     383830       6179
#
#      change  rank
# 0  0.000412   6.0
# 1 -0.000060  88.0
# 2  0.000021  64.0
# 3  0.000017  69.0
# 4  0.000086  49.0

# %%
df.isnull().sum()
# Out:
# name                                      0
# date                                      0
# tweets                                    0
# count_tweets                            202
# avg_tweet_likes                           0
# avg_tweet_retweets                        0
# chatter                                 558
# followers                                 0
# following                                 0
# change                                    0
# rank                                      0
# rank on the following day (dpv1)          0
# rank 2 days later            ( dpv2)      0
# rank 3 days later          (dpv3)         0
# dtype: int64

# %%
#NEW FEATURE COUNTING THE NUMBER OF MENTIONS
def mention_count(text):
    return text.count('@')

# %%
df['mentions'] = df['tweets'].apply(mention_count)
df_pred['mentions'] = df_pred['tweets'].apply(mention_count)

# %%
df['Total_likes_a_day'] = df['count_tweets']*df['avg_tweet_likes']
df['Total_retweets'] = df['avg_tweet_retweets']*df['count_tweets']
df['Followers_following_ratio'] = df['followers']/df['following']
df['engagement'] = df['Total_likes_a_day']/df['followers']

# %%
df.head()
# Out:
#          name       date                                             tweets  \
# 0  company_46 2021-10-23  [{'text': '.@PM360online calls the work of our...
# 1  company_17 2021-10-23  [{'text': '@Amyrive21803741 Yikes! Sorry to he...
# 2  company_91 2021-10-23  [{'text': 'Hellmannâ€™s x AE collab. Dropping ...
# 3   company_2 2021-10-23  [{'text': '@Charli3BiNks ðŸ‘ ðŸ‘ ðŸ‘ Ok, we...
# 4  company_38 2021-10-23                                                 []
#
#    count_tweets  avg_tweet_likes  avg_tweet_retweets chatter  followers  \
# 0           2.0         2.000000               1.000     NaN      72753
# 1           3.0         0.000000               0.000     NaN     501445
# 2          10.0       122.800000               3.100     NaN     571479
# 3           7.0         0.714286               0.000     NaN      60221
# 4         240.0         0.741667               0.075     NaN     383493
#
#    following    change  rank  rank on the following day (dpv1)  \
# 0        496  0.000110  32.0                              29.0
# 1         65 -0.000088  91.0                              81.0
# 2       2999  0.000002  68.0                              61.0
# 3        766  0.000017  57.0                              52.0
# 4       6181  0.000034  54.0                              45.0
#
#    rank 2 days later            ( dpv2)  rank 3 days later          (dpv3)  \
# 0                                  25.0                               31.0
# 1                                  83.0                               84.0
# 2                                  86.0                               92.0
# 3                                  55.0                               51.0
# 4                                  35.0                               65.0
#
#    mentions  Total_likes_a_day  Total_retweets  Followers_following_ratio  \
# 0         1                4.0             2.0                 146.679435
# 1         3                0.0             0.0                7714.538462
# 2         7             1228.0            31.0                 190.556519
# 3         7                5.0             0.0                  78.617493
# 4         0              178.0            18.0                  62.043844
#
#    engagement
# 0    0.000055
# 1    0.000000
# 2    0.002149
# 3    0.000083
# 4    0.000464

# %% [markdown]
# SENTIMENT ANALYSIS ON TEXT

# %%
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

import string
from collections import Counter

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sameer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sameer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sameer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\sameer\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
#THE FUNCTION WILL RETURN A VALUE OF +1 TO POSITIVE AND -1 TO NEGATIVE SENTENCE

def sentiment_analyse(text):
    lower_case = text.lower()
    cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))
    tokenized_words = word_tokenize(cleaned_text, "english")
    
    
    score = SentimentIntensityAnalyzer().polarity_scores(cleaned_text)
    if 5*score['neg'] > score['pos']:
        return -1
    elif 5*score['neg'] < score['pos']:
        return 1
    else:
        return 0

# %%
df['tweets'] = df['tweets'].apply(sentiment_analyse)
df_pred['tweets'] = df_pred['tweets'].apply(sentiment_analyse)

# %%
df.head()
# Out:
#          name       date  tweets  count_tweets  avg_tweet_likes  \
# 0  company_46 2021-10-23       1           2.0         2.000000
# 1  company_17 2021-10-23       1           3.0         0.000000
# 2  company_91 2021-10-23       1          10.0       122.800000
# 3   company_2 2021-10-23       1           7.0         0.714286
# 4  company_38 2021-10-23       0         240.0         0.741667
#
#    avg_tweet_retweets chatter  followers  following    change  rank  \
# 0               1.000     NaN      72753        496  0.000110  32.0
# 1               0.000     NaN     501445         65 -0.000088  91.0
# 2               3.100     NaN     571479       2999  0.000002  68.0
# 3               0.000     NaN      60221        766  0.000017  57.0
# 4               0.075     NaN     383493       6181  0.000034  54.0
#
#    rank on the following day (dpv1)  rank 2 days later            ( dpv2)  \
# 0                              29.0                                  25.0
# 1                              81.0                                  83.0
# 2                              61.0                                  86.0
# 3                              52.0                                  55.0
# 4                              45.0                                  35.0
#
#    rank 3 days later          (dpv3)  mentions  Total_likes_a_day  \
# 0                               31.0         1                4.0
# 1                               84.0         3                0.0
# 2                               92.0         7             1228.0
# 3                               51.0         7                5.0
# 4                               65.0         0              178.0
#
#    Total_retweets  Followers_following_ratio  engagement
# 0             2.0                 146.679435    0.000055
# 1             0.0                7714.538462    0.000000
# 2            31.0                 190.556519    0.002149
# 3             0.0                  78.617493    0.000083
# 4            18.0                  62.043844    0.000464

# %%
sns.set_style('whitegrid')
sns.countplot(x ='tweets',data =df)

# %%
#FILLING ALL THE NULL VALUES WITH 0
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#          name       date  tweets  count_tweets  avg_tweet_likes  \
# 0  company_46 2021-10-23       1           2.0         2.000000
# 1  company_17 2021-10-23       1           3.0         0.000000
# 2  company_91 2021-10-23       1          10.0       122.800000
# 3   company_2 2021-10-23       1           7.0         0.714286
# 4  company_38 2021-10-23       0         240.0         0.741667
#
#    avg_tweet_retweets chatter  followers  following    change  rank  \
# 0               1.000       0      72753        496  0.000110  32.0
# 1               0.000       0     501445         65 -0.000088  91.0
# 2               3.100       0     571479       2999  0.000002  68.0
# 3               0.000       0      60221        766  0.000017  57.0
# 4               0.075       0     383493       6181  0.000034  54.0
#
#    rank on the following day (dpv1)  rank 2 days later            ( dpv2)  \
# 0                              29.0                                  25.0
# 1                              81.0                                  83.0
# 2                              61.0                                  86.0
# 3                              52.0                                  55.0
# 4                              45.0                                  35.0
#
#    rank 3 days later          (dpv3)  mentions  Total_likes_a_day  \
# 0                               31.0         1                4.0
# 1                               84.0         3                0.0
# 2                               92.0         7             1228.0
# 3                               51.0         7                5.0
# 4                               65.0         0              178.0
#
#    Total_retweets  Followers_following_ratio  engagement
# 0             2.0                 146.679435    0.000055
# 1             0.0                7714.538462    0.000000
# 2            31.0                 190.556519    0.002149
# 3             0.0                  78.617493    0.000083
# 4            18.0                  62.043844    0.000464

# %%
df.describe()
# Out:
#             tweets  count_tweets  avg_tweet_likes  avg_tweet_retweets  \
# count  1209.000000   1209.000000      1209.000000         1209.000000
# mean      0.533499     11.267163        39.418935            8.591025
# std       0.738540     34.312412       387.018589           82.324540
# min      -1.000000      0.000000         0.000000            0.000000
# 25%       0.000000      1.000000         0.000000            0.000000
# 50%       1.000000      3.000000         1.000000            0.166667
# 75%       1.000000     11.000000         8.000000            2.000000
# max       1.000000    520.000000     11462.375000         2166.375000
#
#           followers      following       change         rank  \
# count  1.209000e+03    1209.000000  1209.000000  1209.000000
# mean   1.122702e+06    8081.205128     0.000115    47.000000
# std    2.984283e+06   17708.493189     0.000305    26.855589
# min    5.110700e+04       4.000000    -0.000357     1.000000
# 25%    1.094500e+05     337.000000     0.000000    24.000000
# 50%    3.250900e+05    1397.000000     0.000064    47.000000
# 75%    7.733170e+05    5489.000000     0.000157    70.500000
# max    2.389704e+07  105215.000000     0.007013    93.000000
#
#        rank on the following day (dpv1)  rank 2 days later            ( dpv2)  \
# count                       1209.000000                           1209.000000
# mean                          47.000000                             47.000000
# std                           26.855828                             26.855836
# min                            1.000000                              1.000000
# 25%                           24.000000                             24.000000
# 50%                           47.000000                             47.000000
# 75%                           70.000000                             70.000000
# max                           93.000000                             93.000000
#
#        rank 3 days later          (dpv3)     mentions  Total_likes_a_day  \
# count                        1209.000000  1209.000000        1209.000000
# mean                           47.000000     5.732010         261.060380
# std                            26.855836     7.473417        2882.263687
# min                             1.000000     0.000000           0.000000
# 25%                            24.000000     0.000000           0.000000
# 50%                            47.000000     2.000000           6.000000
# 75%                            70.000000     9.000000          33.000000
# max                            93.000000    47.000000       91699.000000
#
#        Total_retweets  Followers_following_ratio   engagement
# count     1209.000000                1209.000000  1209.000000
# mean        57.574855                6232.793886     0.000221
# std        708.131573               20390.613599     0.003024
# min          0.000000                   2.050107     0.000000
# 25%          0.000000                  43.777786     0.000000
# 50%          1.000000                 180.341246     0.000025
# 75%          7.000000                 885.395626     0.000101
# max      17331.000000              134082.800000     0.103775

# %%
#DEFINING THE NEW VARIABLES FOR THE TEST DATASET

df_pred['Total_likes_a_day'] = df_pred['count_tweets']*df_pred['avg_tweet_likes']
df_pred['Total_retweets'] = df_pred['avg_tweet_retweets']*df_pred['count_tweets']
df_pred['Followers_following_ratio'] = df_pred['followers']/df_pred['following']
df_pred['engagement'] = df_pred['Total_likes_a_day']/df_pred['followers']

# %%
df_pred.head()
# Out:
#    ID  tweets  count_tweets  avg_tweet_likes  avg_tweet_retweets  \
# 0   1      -1           2.0        10.000000                 0.5
# 1   2       1           3.0         0.333333                 0.0
# 2   3      -1          10.0        24.500000                 2.3
# 3   4       1           4.0         0.250000                 0.0
# 4   5      -1          20.0         0.300000                 0.0
#
#                                              chatter  followers  following  \
# 0  [{'text': 'RT @SligoLGFA: Sligo LGFA countdown...      72930        496
# 1  [{'text': '@Abercrombie I bought a fewT-shirtâ...     501153         65
# 2  [{'text': '@AEO I re designed your logo for fu...     571362       1290
# 3  [{'text': '@MurrayLinus @BelfastHome @tinamcke...      60224        767
# 4  [{'text': 'RT @BeciMahnken: Trams going to gat...     383830       6179
#
#      change  rank  mentions  Total_likes_a_day  Total_retweets  \
# 0  0.000412   6.0         0               20.0             1.0
# 1 -0.000060  88.0         3                1.0             0.0
# 2  0.000021  64.0        10              245.0            23.0
# 3  0.000017  69.0         4                1.0             0.0
# 4  0.000086  49.0        20                6.0             0.0
#
#    Followers_following_ratio  engagement
# 0                 147.036290    0.000274
# 1                7710.046154    0.000002
# 2                 442.916279    0.000429
# 3                  78.518905    0.000017
# 4                  62.118466    0.000016

# %%
df.columns
# Out:
# Index(['name', 'date', 'tweets', 'count_tweets', 'avg_tweet_likes',
#        'avg_tweet_retweets', 'chatter', 'followers', 'following', 'change',
#        'rank', 'rank on the following day (dpv1)',
#        'rank 2 days later            ( dpv2)',
#        'rank 3 days later          (dpv3)', 'mentions', 'Total_likes_a_day',
#        'Total_retweets', 'Followers_following_ratio', 'engagement'],
#       dtype='object')

# %%
column_names = ['name', 'date', 'tweets', 'count_tweets', 'avg_tweet_likes',
       'avg_tweet_retweets', 'chatter', 'followers', 'following', 'change','Total_likes_a_day',
       'Total_retweets', 'Followers_following_ratio', 'engagement','mentions','rank', 'rank on the following day (dpv1)',
       'rank 2 days later            ( dpv2)',
       'rank 3 days later          (dpv3)']

# %%
#REINDEXING THE DATAFRAME TO GET ALL DEPENDENDENT VARIABLES ON ONESIDE

df = df.reindex(columns=column_names)

# %%
df.head()
# Out:
#          name       date  tweets  count_tweets  avg_tweet_likes  \
# 0  company_46 2021-10-23       1           2.0         2.000000
# 1  company_17 2021-10-23       1           3.0         0.000000
# 2  company_91 2021-10-23       1          10.0       122.800000
# 3   company_2 2021-10-23       1           7.0         0.714286
# 4  company_38 2021-10-23       0         240.0         0.741667
#
#    avg_tweet_retweets chatter  followers  following    change  \
# 0               1.000       0      72753        496  0.000110
# 1               0.000       0     501445         65 -0.000088
# 2               3.100       0     571479       2999  0.000002
# 3               0.000       0      60221        766  0.000017
# 4               0.075       0     383493       6181  0.000034
#
#    Total_likes_a_day  Total_retweets  Followers_following_ratio  engagement  \
# 0                4.0             2.0                 146.679435    0.000055
# 1                0.0             0.0                7714.538462    0.000000
# 2             1228.0            31.0                 190.556519    0.002149
# 3                5.0             0.0                  78.617493    0.000083
# 4              178.0            18.0                  62.043844    0.000464
#
#    mentions  rank  rank on the following day (dpv1)  \
# 0         1  32.0                              29.0
# 1         3  91.0                              81.0
# 2         7  68.0                              61.0
# 3         7  57.0                              52.0
# 4         0  54.0                              45.0
#
#    rank 2 days later            ( dpv2)  rank 3 days later          (dpv3)
# 0                                  25.0                               31.0
# 1                                  83.0                               84.0
# 2                                  86.0                               92.0
# 3                                  55.0                               51.0
# 4                                  35.0                               65.0

# %%
column_names_pred = ['name', 'date', 'tweets', 'count_tweets', 'avg_tweet_likes',
       'avg_tweet_retweets', 'chatter', 'followers', 'following', 'change','Total_likes_a_day',
       'Total_retweets', 'Followers_following_ratio', 'engagement','mentions','rank']

# %%
df_pred = df_pred.reindex(columns=column_names_pred)

# %%
df.drop(['chatter'], axis=1, inplace = True)
df_pred.drop(['chatter'], axis=1, inplace = True)

# %%
df.head()
# Out:
#          name       date  tweets  count_tweets  avg_tweet_likes  \
# 0  company_46 2021-10-23       1           2.0         2.000000
# 1  company_17 2021-10-23       1           3.0         0.000000
# 2  company_91 2021-10-23       1          10.0       122.800000
# 3   company_2 2021-10-23       1           7.0         0.714286
# 4  company_38 2021-10-23       0         240.0         0.741667
#
#    avg_tweet_retweets  followers  following    change  Total_likes_a_day  \
# 0               1.000      72753        496  0.000110                4.0
# 1               0.000     501445         65 -0.000088                0.0
# 2               3.100     571479       2999  0.000002             1228.0
# 3               0.000      60221        766  0.000017                5.0
# 4               0.075     383493       6181  0.000034              178.0
#
#    Total_retweets  Followers_following_ratio  engagement  mentions  rank  \
# 0             2.0                 146.679435    0.000055         1  32.0
# 1             0.0                7714.538462    0.000000         3  91.0
# 2            31.0                 190.556519    0.002149         7  68.0
# 3             0.0                  78.617493    0.000083         7  57.0
# 4            18.0                  62.043844    0.000464         0  54.0
#
#    rank on the following day (dpv1)  rank 2 days later            ( dpv2)  \
# 0                              29.0                                  25.0
# 1                              81.0                                  83.0
# 2                              61.0                                  86.0
# 3                              52.0                                  55.0
# 4                              45.0                                  35.0
#
#    rank 3 days later          (dpv3)
# 0                               31.0
# 1                               84.0
# 2                               92.0
# 3                               51.0
# 4                               65.0

# %%
df_pred.head()
# Out:
#    name  date  tweets  count_tweets  avg_tweet_likes  avg_tweet_retweets  \
# 0   NaN   NaN      -1           2.0        10.000000                 0.5
# 1   NaN   NaN       1           3.0         0.333333                 0.0
# 2   NaN   NaN      -1          10.0        24.500000                 2.3
# 3   NaN   NaN       1           4.0         0.250000                 0.0
# 4   NaN   NaN      -1          20.0         0.300000                 0.0
#
#    followers  following    change  Total_likes_a_day  Total_retweets  \
# 0      72930        496  0.000412               20.0             1.0
# 1     501153         65 -0.000060                1.0             0.0
# 2     571362       1290  0.000021              245.0            23.0
# 3      60224        767  0.000017                1.0             0.0
# 4     383830       6179  0.000086                6.0             0.0
#
#    Followers_following_ratio  engagement  mentions  rank
# 0                 147.036290    0.000274         0   6.0
# 1                7710.046154    0.000002         3  88.0
# 2                 442.916279    0.000429        10  64.0
# 3                  78.518905    0.000017         4  69.0
# 4                  62.118466    0.000016        20  49.0

# %%
corr_with_rank_day1 = df.drop(["name","date",'rank 2 days later            ( dpv2)',
       'rank 3 days later          (dpv3)'], axis=1).corr()
plot_data = corr_with_rank_day1["rank on the following day (dpv1)"].sort_values(ascending=True)
plt.figure(figsize=(12,6))
plot_data.plot.bar()
plt.title("Correlations with the Sale Price")
plt.show()
del plot_data

# %%
#CONVERTING DATAFRAME TO NUMPY ARRAYS
X = df.iloc[:, 2:-3].values
y = df.iloc[:, -3:].values

# %%
print(X)
# Out:
# [[1.00000000e+00 2.00000000e+00 2.00000000e+00 ... 5.49805506e-05
#   1.00000000e+00 3.20000000e+01]
#  [1.00000000e+00 3.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   3.00000000e+00 9.10000000e+01]
#  [1.00000000e+00 1.00000000e+01 1.22800000e+02 ... 2.14881037e-03
#   7.00000000e+00 6.80000000e+01]
#  ...
#  [1.00000000e+00 2.00000000e+01 1.50000000e-01 ... 9.16472680e-06
#   2.00000000e+01 5.20000000e+01]
#  [1.00000000e+00 2.00000000e+00 5.50000000e+00 ... 1.00564073e-04
#   0.00000000e+00 9.20000000e+01]
#  [1.00000000e+00 2.00000000e+00 2.00000000e+00 ... 2.29923378e-05
#   1.00000000e+00 8.70000000e+01]]

# %%
print(X[0])
# Out:
# [1.00000000e+00 2.00000000e+00 2.00000000e+00 1.00000000e+00
#  7.27530000e+04 4.96000000e+02 1.09973000e-04 4.00000000e+00
#  2.00000000e+00 1.46679435e+02 5.49805506e-05 1.00000000e+00
#  3.20000000e+01]

# %%
print(y)
# Out:
# [[29. 25. 31.]
#  [81. 83. 84.]
#  [61. 86. 92.]
#  ...
#  [58. 64. 44.]
#  [78. 93. 93.]
#  [87. 84. 88.]]

# %%
df.isnull().sum()
# Out:
# name                                    0
# date                                    0
# tweets                                  0
# count_tweets                            0
# avg_tweet_likes                         0
# avg_tweet_retweets                      0
# followers                               0
# following                               0
# change                                  0
# Total_likes_a_day                       0
# Total_retweets                          0
# Followers_following_ratio               0
# engagement                              0
# mentions                                0
# rank                                    0
# rank on the following day (dpv1)        0
# rank 2 days later            ( dpv2)    0
# rank 3 days later          (dpv3)       0
# dtype: int64

# %%
#TRAIN TEST SPLIT
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15,random_state=42)

# %% [markdown]
# # MODEL CREATION

# %% [markdown]
# # xgboost

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
from xgboost import XGBRegressor
from sklearn.multioutput import MultiOutputRegressor

import xgboost

# %%
#Define the estimator
estimator = XGBRegressor(
    objective = 'reg:squarederror'

    )

# Define the model
my_model = MultiOutputRegressor(estimator = estimator, n_jobs = -1).fit(X_train, y_train)

# %%
y_pred = my_model.predict(X_test)

# %%
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 18.776148265298282

# %%
np.concatenate((y_test, y_pred), axis=1)
# Out:
# array([[45.        , 53.        , 50.        , 29.62282372, 21.28217316,
#         34.32408905],
#        [46.        ,  2.        ,  1.        , 38.81072235, 37.77988815,
#         12.69128513],
#        [ 2.        , 23.        , 40.        , 47.95705795, 56.96223831,
#         52.14086533],
#        ...,
#        [10.        , 18.        ,  7.        , 29.14024925, 16.35372543,
#         26.63450241],
#        [ 3.        ,  3.        ,  3.        ,  5.06142569, -1.97644877,
#          3.71120214],
#        [71.        ,  4.        , 62.        , 23.8658371 , 50.31889343,
#         14.92008018]])

# %% [markdown]
# # Regression Chain

# %%
from sklearn.multioutput import RegressorChain
from sklearn.svm import LinearSVR

# %%
model = LinearSVR()
wrapper = RegressorChain(model)
wrapper.fit(X_train,y_train)
# Out:
# RegressorChain(base_estimator=LinearSVR(C=1.0, dual=True, epsilon=0.0,
#                                         fit_intercept=True,
#                                         intercept_scaling=1.0,
#                                         loss='epsilon_insensitive',
#                                         max_iter=1000, random_state=None,
#                                         tol=0.0001, verbose=0),
#                cv=None, order=None, random_state=None)

# %%
y_pred_wrap = wrapper.predict(X_test)

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred_wrap)))
# Out:
# 901.4291333091385

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred_lin = lin_reg.predict(X_test)

# %%
print(y_pred_lin)
# Out:
# [[ 43.64007539  41.32454636  39.21968927]
#  [ 48.69714812  49.36788116  47.88734343]
#  [ 54.66722187  54.35324671  54.79196098]
#  [ 67.407047    68.21358834  66.72007972]
#  [ 44.72795668  46.38100086  44.53045089]
#  [ 58.57505497  59.99069468  57.85190022]
#  [ 19.91284473  20.02699807  20.89591974]
#  [ 35.86864376  35.76312342  35.40257665]
#  [ 78.31447565  77.7672366   77.57331467]
#  [ 73.7085583   73.27123006  73.3909209 ]
#  [ 28.90434834  28.60551703  29.62399482]
#  [ 52.69885812  52.26992601  52.88138133]
#  [ 31.82188069  31.57253648  32.57208973]
#  [ 63.93515566  63.63443256  63.66613139]
#  [ 79.65043127  79.33089468  79.61189846]
#  [ 67.43912915  67.18124718  67.36132219]
#  [ 43.37471785  43.24380971  43.77397211]
#  [ 63.84155514  63.40937533  63.57062046]
#  [ 55.0717222   55.58577978  54.89874362]
#  [ 35.56745631  34.95013342  35.99491805]
#  [ 48.74989919  48.45047875  49.03440789]
#  [ 61.31726849  59.9732738   60.49619544]
#  [ 49.42517873  49.34638984  49.89239119]
#  [ 65.75302182  66.16446175  65.0367824 ]
#  [ 52.05680125  53.5142163   52.1503426 ]
#  [ 24.62375637  24.36387241  25.52153361]
#  [ 38.78670195  38.5851652   38.7280331 ]
#  [ 67.79736734  67.46189275  67.56503369]
#  [ 72.04894581  71.73714558  71.82818216]
#  [ 63.98774493  65.50711713  63.18989682]
#  [ 78.44731622  78.0576875   77.76870512]
#  [ 52.07255069  53.54061245  52.99011848]
#  [ 12.07068427  13.59825026  13.28803053]
#  [ 15.74366296  15.86260756  17.27117598]
#  [ 16.10226375  16.07076459  16.89943573]
#  [ 60.06478851  60.04233672  59.76608651]
#  [ 55.53119893  57.00772865  55.04493188]
#  [ 13.62023573  14.07942782  13.98092729]
#  [ 61.90950259  61.74144947  61.74890613]
#  [ 38.25538777  37.92594513  38.35924502]
#  [ 64.65470544  64.31470043  64.74267099]
#  [ 23.26427638  23.24282324  24.56994307]
#  [ 13.36308465  15.76212325  14.85203485]
#  [ 31.82062799  31.45606475  32.63146006]
#  [ 15.26441341  15.13235598  14.71990331]
#  [ 70.63843275  70.72857666  70.41722584]
#  [ 73.00677371  72.57067119  72.58088994]
#  [ 60.8048197   60.36244719  60.74044163]
#  [ 77.23248787  78.53323871  76.53833905]
#  [ 64.30558593  63.96898774  63.30478933]
#  [ 58.04884699  57.57761605  57.898158  ]
#  [ 16.50983582  16.91723553  18.43453421]
#  [ 18.29361289  18.2021631   19.72033386]
#  [ 27.18696147  26.80768532  27.87179426]
#  [ 37.84978428  37.57374429  38.40971368]
#  [ 25.53335017  25.51412199  26.72648695]
#  [ 34.89984581  34.27465302  35.28783159]
#  [ 66.77163337  66.29626308  66.47660238]
#  [ 57.87073158  57.86054098  57.68992972]
#  [ 65.04771187  64.72982     65.03021379]
#  [ 47.16440404  46.86844618  47.57819085]
#  [ 55.48541616  55.80572722  54.66321429]
#  [ 26.39901502  25.46811067  26.05103753]
#  [ 48.80317447  48.93190583  48.71398386]
#  [ 29.99991409  30.49265861  30.75217769]
#  [ 63.58470658  66.01936278  62.6499429 ]
#  [ 38.31237208  39.97703077  38.54039697]
#  [ 70.18067608  71.33641968  69.29098156]
#  [ 73.49111258  73.17282211  72.82694086]
#  [ 22.32148552  22.26048003  23.41704349]
#  [ 41.59938976  41.38804487  42.92262224]
#  [ 21.05641219  20.78940112  22.03937655]
#  [ 33.54511389  33.17256815  34.05643121]
#  [ 18.01652772  18.13366853  18.73946723]
#  [-11.40426873  -5.35247591  -3.29010718]
#  [ 48.28113545  47.94406147  48.53948364]
#  [ 66.56405763  67.44030799  66.00514619]
#  [ 20.11226819  21.9075079   22.20762425]
#  [ 52.75668104  52.36232881  52.86589026]
#  [ 43.71787038  43.33216224  44.21741137]
#  [ 56.75827049  56.34102292  56.70789713]
#  [ 36.62306674  35.81938172  37.24160499]
#  [ 35.64486526  35.50015455  36.3673126 ]
#  [ 33.41574294  33.22584838  34.11592998]
#  [ 72.98071502  73.4132331   72.24120352]
#  [ 71.58490399  71.77159457  71.06652334]
#  [ 75.64640152  75.14759423  75.04032858]
#  [ 67.16739877  66.73862691  66.86300222]
#  [ 74.59757698  74.57311373  74.23447235]
#  [ 46.6606525   45.1950528   44.7750923 ]
#  [ 53.36187885  52.9957052   53.50097589]
#  [ 53.01933005  50.55396999  52.32628024]
#  [ 42.38762231  42.39417681  42.54922898]
#  [ 46.61389098  48.14325122  46.29598052]
#  [ 70.37911323  69.93270313  69.91870862]
#  [ 75.6266299   75.52056917  75.47056446]
#  [ 77.89456289  77.51919575  77.39198482]
#  [ 28.3522585   27.80193639  29.55462595]
#  [ 28.37786658  28.66633232  28.01854181]
#  [ 67.88505813  67.65748299  67.64337209]
#  [ 62.72036331  64.2521989   61.94221772]
#  [ 66.91658754  66.52824663  66.92029074]
#  [ 34.78678664  35.03118613  35.20674585]
#  [ 42.33327212  43.9032042   43.61257598]
#  [ 51.57964208  51.22844291  51.71426781]
#  [ 55.61755938  55.67050841  54.64637314]
#  [ 54.99547505  56.56164943  54.53882358]
#  [ 39.73893807  40.98382526  39.29681379]
#  [ 53.10740732  54.34020507  53.099731  ]
#  [ 10.93333907   8.39108233   7.98150334]
#  [ 33.90070443  33.53503819  34.35582154]
#  [ 29.24616522  28.37238486  30.07626765]
#  [  4.91105324   3.04715215   6.04072937]
#  [ 73.15244795  73.14179889  72.78172514]
#  [ 29.7893058   29.46252844  30.73909945]
#  [ 60.75195294  60.38664312  60.73439193]
#  [ 59.80055972  60.66632712  59.58511929]
#  [ 60.42928207  59.34048877  58.99486438]
#  [  5.01993983   7.01853124   5.62905198]
#  [ 78.87893806  78.46909758  78.32283376]
#  [ 78.80783957  78.36379476  77.99917471]
#  [ 69.40024777  69.04265864  69.16063098]
#  [ 48.89156329  49.19682605  48.04000882]
#  [ 39.05632838  40.61619544  39.11389492]
#  [ 70.42221643  69.88404322  70.34917817]
#  [ 74.30529345  74.16940835  73.72680171]
#  [ 29.07139778  28.92516896  29.79634883]
#  [ 20.56961352  21.57953454  21.38378496]
#  [ 75.17798117  75.3041369   74.63543461]
#  [ 51.89244102  52.19795152  52.0852756 ]
#  [ 53.70691567  53.34541911  53.78970705]
#  [ 52.12216281  51.7928539   52.05426587]
#  [ 64.61170644  63.21371084  63.55634989]
#  [ 55.24574733  54.72774533  55.1483091 ]
#  [ 46.60745802  48.11814595  46.42541951]
#  [ 67.44019751  67.1459193   66.97378635]
#  [ 73.57243899  74.35533044  72.88751433]
#  [ 38.78564578  38.59407382  39.09421159]
#  [ 53.34406843  55.03293648  53.26731622]
#  [ 53.85144538  55.38296683  53.3722309 ]
#  [ 40.25240993  39.67113448  40.58476836]
#  [ 37.92317338  37.56059019  37.32166643]
#  [ 13.45449711  15.05910191  13.84024531]
#  [ 59.44533632  60.74820356  58.80702097]
#  [ 23.27780856  23.65525532  24.19590704]
#  [  8.87199859   4.74537548   3.03650478]
#  [  4.97373838   6.70856582   5.50197476]
#  [ 75.76640049  75.2417879   75.07899819]
#  [ 42.81560053  43.21865665  43.14911721]
#  [ 43.45373239  43.08700276  44.10273161]
#  [ 66.53452015  66.00167985  66.27477056]
#  [ 38.67622821  38.00178467  39.47755728]
#  [ 62.00081737  61.68033716  61.93996684]
#  [ 55.25352817  53.93597248  54.60617364]
#  [ 36.73753825  38.46799428  36.93216961]
#  [ 29.90165195  30.69759178  29.25744542]
#  [ 63.51715109  63.38956982  64.52405538]
#  [ 49.36607067  49.00996264  49.54178898]
#  [ 37.41424603  37.10145325  37.94918365]
#  [ 34.51507745  33.96892523  34.87904189]
#  [ 77.74767585  77.34664438  77.29601441]
#  [ 50.14260168  49.86027768  50.1240309 ]
#  [ 66.2078473   65.7366138   65.52134766]
#  [ 24.0059552   23.87309285  25.14572106]
#  [ 49.93305463  49.83643022  50.24692267]
#  [  9.21094041  10.81496691   9.31436447]
#  [ 29.31602156  28.75505831  29.90194904]
#  [ 36.10624151  35.86401983  36.53258671]
#  [ 51.93087493  51.57518506  52.23489312]
#  [ 74.99767464  73.91457841  74.77332082]
#  [ 30.72404365  30.26085163  31.26546805]
#  [ 80.8480415   80.31918454  80.06914831]
#  [ 22.36833766  22.13060692  23.33522053]
#  [ 52.75853932  51.96667446  52.56314458]
#  [ 42.85393802  44.30645189  43.14774958]
#  [ 32.0456552   32.38504198  32.45614801]
#  [ 19.62080375  23.97379553  18.54472064]
#  [ 64.57104886  64.14773577  64.48750362]
#  [ 45.81058627  45.53824933  46.23517747]
#  [ 21.56960631  21.45580857  22.53118249]
#  [  4.7411721    5.63736039   5.74874458]
#  [ 28.0274106   27.71971181  28.72294015]]

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred_lin)))
# Out:
# 19.8698597498763

# %% [markdown]
# # knn

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(algorithm='auto', leaf_size=40, metric='minkowski',metric_params=None, n_jobs=None, n_neighbors=6, p=2, weights='distance')

# %%
knn_1 = KNeighborsRegressor(algorithm='auto', leaf_size=40, metric='minkowski',metric_params=None, n_jobs=None, n_neighbors=7, p=1, weights='distance')

# %%
cross_val_score(KNeighborsRegressor(algorithm='auto', leaf_size=40, metric='minkowski',metric_params=None, n_jobs=None, n_neighbors=6, p=1, weights='distance'),X,y,cv=5)
# Out:
# array([0.64399645, 0.67400834, 0.64348024, 0.63210103, 0.6212597 ])

# %%
knn_1.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=40, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=7, p=1,
#                     weights='distance')

# %%
y_pred_knn = knn_1.predict(X_test)

# %%
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred_knn)))
# Out:
# 15.462176092972905

# %% [markdown]
# Grid Search on KNN

# %%
leaf_size = range(10,40,5)
n_neighbors = range(4,20)
p =[1,2]
weights= ['uniform','distance']

hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p,weights = weights)
knn_2= KNeighborsRegressor()
reg = GridSearchCV(knn_2, hyperparameters, cv=5)
best_model = reg.fit(X_train,y_train)

print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
print('Best weight:', best_model.best_estimator_.get_params()['weights'])
# Out:
# Best leaf_size: 10
# Best p: 1
# Best n_neighbors: 11
# Best weight: distance

# %%
knn_3 = KNeighborsRegressor(algorithm='auto', leaf_size=10, metric='minkowski',metric_params=None, n_jobs=None, n_neighbors=11, p=1, weights='distance')

# %%
knn_3.fit(X_train,y_train)
y_pred_knn_3 = knn_3.predict(X_test)

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred_knn_3)))
# Out:
# 15.480732361148126

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
ran = RandomForestRegressor()

# %%
ran.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_pred_ran = ran.predict(X_test)

# %%
print(y_pred_ran)
# Out:
# [[44.7  31.7  29.9 ]
#  [48.   47.9  42.6 ]
#  [58.8  56.7  50.7 ]
#  [68.6  65.8  59.8 ]
#  [48.3  54.5  50.2 ]
#  [61.9  54.4  39.5 ]
#  [11.7   8.7   9.3 ]
#  [27.6  34.8  41.5 ]
#  [75.85 87.1  86.6 ]
#  [72.1  71.   70.2 ]
#  [42.4  39.6  23.4 ]
#  [57.1  56.1  57.  ]
#  [25.9  21.8  19.4 ]
#  [47.7  47.6  53.  ]
#  [47.65 60.65 66.2 ]
#  [65.1  69.6  69.7 ]
#  [42.9  45.7  37.15]
#  [57.7  50.4  50.5 ]
#  [46.2  42.9  50.3 ]
#  [31.3  28.8  22.5 ]
#  [60.8  48.8  63.6 ]
#  [56.8  57.7  64.  ]
#  [52.4  42.1  57.9 ]
#  [77.8  74.7  77.5 ]
#  [55.85 51.9  43.3 ]
#  [22.5  16.9  21.  ]
#  [44.2  40.6  38.4 ]
#  [73.6  67.95 71.3 ]
#  [62.4  53.95 61.3 ]
#  [61.7  71.3  53.2 ]
#  [51.9  76.3  68.  ]
#  [48.95 44.9  34.35]
#  [ 1.7   1.9   4.  ]
#  [ 5.4   6.2   7.3 ]
#  [14.4  16.3  14.4 ]
#  [45.5  40.   46.2 ]
#  [56.2  52.6  44.7 ]
#  [ 6.9   9.    6.5 ]
#  [50.7  61.1  56.4 ]
#  [33.15 56.3  51.1 ]
#  [66.85 61.2  69.6 ]
#  [13.   10.5  14.2 ]
#  [13.5  11.7  22.2 ]
#  [20.6  22.9  19.4 ]
#  [ 8.2   9.9   7.4 ]
#  [72.1  72.5  65.3 ]
#  [68.3  67.7  63.  ]
#  [69.8  60.   69.6 ]
#  [54.35 63.   46.  ]
#  [55.6  62.7  55.8 ]
#  [61.5  58.7  58.1 ]
#  [ 7.3   6.9   5.6 ]
#  [11.   15.7  17.  ]
#  [17.9  26.7  30.9 ]
#  [27.9  50.65 36.8 ]
#  [14.9   9.2  11.1 ]
#  [37.6  31.5  34.2 ]
#  [76.6  81.2  74.7 ]
#  [36.2  44.2  56.8 ]
#  [61.6  46.9  50.6 ]
#  [44.8  33.7  56.2 ]
#  [49.   46.1  51.  ]
#  [19.8  20.3  39.  ]
#  [42.8  42.2  48.7 ]
#  [42.7  43.3  31.1 ]
#  [62.9  67.8  67.2 ]
#  [44.9  49.3  44.1 ]
#  [51.7  61.   60.2 ]
#  [79.1  77.9  83.6 ]
#  [18.4  10.9  11.7 ]
#  [53.   36.7  34.4 ]
#  [15.1  14.4  17.  ]
#  [36.4  42.2  35.5 ]
#  [15.6  15.8  16.2 ]
#  [ 1.7   2.1   4.2 ]
#  [50.9  50.4  54.6 ]
#  [74.2  71.25 76.  ]
#  [20.2  43.3  31.7 ]
#  [66.1  49.5  57.8 ]
#  [39.3  35.6  37.8 ]
#  [67.7  65.9  49.85]
#  [29.9  28.9  27.6 ]
#  [37.   36.   35.2 ]
#  [31.9  25.5  21.2 ]
#  [75.8  74.65 73.2 ]
#  [54.2  52.7  55.15]
#  [82.6  83.15 83.2 ]
#  [71.2  80.9  71.5 ]
#  [81.1  77.8  73.8 ]
#  [44.5  38.9  43.5 ]
#  [46.3  44.2  55.2 ]
#  [54.6  54.1  56.5 ]
#  [47.2  43.3  41.2 ]
#  [50.8  35.75 34.5 ]
#  [81.4  77.5  77.2 ]
#  [48.1  62.65 66.  ]
#  [75.85 81.   75.4 ]
#  [23.   25.3  39.7 ]
#  [21.4  19.3  17.  ]
#  [80.9  78.   78.  ]
#  [55.4  69.5  45.9 ]
#  [61.3  66.6  79.5 ]
#  [31.8  32.4  29.6 ]
#  [41.8  32.3  22.9 ]
#  [36.5  41.5  31.2 ]
#  [60.9  55.1  52.4 ]
#  [59.1  53.2  52.2 ]
#  [43.6  39.5  42.7 ]
#  [62.65 63.   67.2 ]
#  [39.   32.6  34.  ]
#  [30.3  28.5  34.1 ]
#  [18.9  24.8  20.5 ]
#  [ 3.2   5.7   5.7 ]
#  [78.3  75.2  78.8 ]
#  [20.8  20.8  19.2 ]
#  [62.7  69.2  74.8 ]
#  [62.5  63.5  71.3 ]
#  [57.6  60.8  57.3 ]
#  [ 4.7   4.3   3.7 ]
#  [67.15 73.4  76.9 ]
#  [54.2  79.6  65.35]
#  [80.7  77.1  73.65]
#  [58.8  52.7  40.3 ]
#  [48.1  38.4  39.6 ]
#  [81.5  80.4  84.  ]
#  [82.1  81.25 81.9 ]
#  [33.7  39.5  24.4 ]
#  [18.6  23.4  25.8 ]
#  [74.6  73.55 77.3 ]
#  [42.3  51.55 53.1 ]
#  [52.   60.8  57.3 ]
#  [48.8  45.9  49.7 ]
#  [73.6  74.   70.6 ]
#  [57.1  57.6  62.3 ]
#  [47.2  43.8  41.  ]
#  [75.65 61.2  58.5 ]
#  [54.9  57.6  60.35]
#  [49.   42.6  36.8 ]
#  [53.   49.2  36.2 ]
#  [59.7  51.6  37.2 ]
#  [34.   37.4  37.7 ]
#  [56.15 50.7  38.1 ]
#  [15.9  15.6  18.2 ]
#  [80.1  77.4  77.8 ]
#  [18.8  21.7  21.8 ]
#  [18.1  17.3  33.5 ]
#  [ 1.8   2.1   2.7 ]
#  [77.7  73.25 78.  ]
#  [42.9  36.5  38.2 ]
#  [53.4  42.1  42.9 ]
#  [64.   67.7  59.15]
#  [33.   33.2  33.1 ]
#  [32.65 38.2  38.4 ]
#  [62.9  62.   57.1 ]
#  [30.9  38.35 52.5 ]
#  [25.4  16.4  15.1 ]
#  [59.   48.2  50.5 ]
#  [62.6  61.85 71.6 ]
#  [32.9  35.2  22.  ]
#  [32.7  33.1  27.8 ]
#  [70.   76.8  75.5 ]
#  [38.7  44.2  45.8 ]
#  [81.5  73.2  74.4 ]
#  [ 7.6  14.4  16.3 ]
#  [45.6  63.8  63.55]
#  [10.2  11.1  10.7 ]
#  [29.   30.1  26.3 ]
#  [48.8  37.   31.8 ]
#  [47.7  46.6  49.1 ]
#  [75.5  73.2  76.9 ]
#  [21.9  27.7  27.4 ]
#  [65.4  44.4  61.  ]
#  [28.3  20.2  24.7 ]
#  [41.9  46.3  47.8 ]
#  [38.8  36.5  35.7 ]
#  [30.7  42.45 41.1 ]
#  [25.5  23.   18.3 ]
#  [50.7  61.4  63.3 ]
#  [46.4  53.8  45.3 ]
#  [25.6  21.7  36.3 ]
#  [ 2.3   2.7   3.8 ]
#  [24.2  41.1  24.3 ]]

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred_ran)))
# Out:
# 18.928568007463927

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
dectree = DecisionTreeRegressor()

# %%
dectree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
y_pred_dec =dectree.predict(X_test)

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred_dec)))
# Out:
# 24.16259596889465

# %%
df_pred.head()
# Out:
#    name  date  tweets  count_tweets  avg_tweet_likes  avg_tweet_retweets  \
# 0   NaN   NaN      -1           2.0        10.000000                 0.5
# 1   NaN   NaN       1           3.0         0.333333                 0.0
# 2   NaN   NaN      -1          10.0        24.500000                 2.3
# 3   NaN   NaN       1           4.0         0.250000                 0.0
# 4   NaN   NaN      -1          20.0         0.300000                 0.0
#
#    followers  following    change  Total_likes_a_day  Total_retweets  \
# 0      72930        496  0.000412               20.0             1.0
# 1     501153         65 -0.000060                1.0             0.0
# 2     571362       1290  0.000021              245.0            23.0
# 3      60224        767  0.000017                1.0             0.0
# 4     383830       6179  0.000086                6.0             0.0
#
#    Followers_following_ratio  engagement  mentions  rank
# 0                 147.036290    0.000274         0   6.0
# 1                7710.046154    0.000002         3  88.0
# 2                 442.916279    0.000429        10  64.0
# 3                  78.518905    0.000017         4  69.0
# 4                  62.118466    0.000016        20  49.0

# %%
df_pred.isnull().sum()
# Out:
# name                         744
# date                         744
# tweets                         0
# count_tweets                  90
# avg_tweet_likes                0
# avg_tweet_retweets             0
# followers                      0
# following                      0
# change                         0
# Total_likes_a_day             90
# Total_retweets                90
# Followers_following_ratio      0
# engagement                    90
# mentions                       0
# rank                           0
# dtype: int64

# %%
df_pred.fillna(0, inplace=True)

# %%
X_sub = df_pred.iloc[:, 2:].values

# %%
print(X_sub)
# Out:
# [[-1.00000000e+00  2.00000000e+00  1.00000000e+01 ...  2.74235568e-04
#    0.00000000e+00  6.00000000e+00]
#  [ 1.00000000e+00  3.00000000e+00  3.33333333e-01 ...  1.99539861e-06
#    3.00000000e+00  8.80000000e+01]
#  [-1.00000000e+00  1.00000000e+01  2.45000000e+01 ...  4.28799955e-04
#    1.00000000e+01  6.40000000e+01]
#  ...
#  [-1.00000000e+00  2.00000000e+01  5.00000000e-02 ...  3.05169262e-06
#    2.00000000e+01  1.40000000e+01]
#  [ 1.00000000e+00  3.00000000e+00  1.16666667e+01 ...  3.20251810e-04
#    1.00000000e+00  6.00000000e+01]
#  [ 1.00000000e+00  2.00000000e+00  4.00000000e+00 ...  4.60034503e-05
#    0.00000000e+00  6.90000000e+01]]

# %%
y_sub = knn_3.predict(X_sub)

# %%
print(y_sub)
# Out:
# [[24.22032411 19.66012248 20.9451883 ]
#  [83.74432453 79.83431387 83.3637825 ]
#  [69.22627362 75.45714269 78.99265217]
#  ...
#  [50.82107502 53.71781678 53.93168473]
#  [55.43489967 56.83398392 56.3567513 ]
#  [82.66166833 82.52758354 83.73856519]]

# %%
#CONVERTING THE ARRAY TO CSV FILE
df_submit = pd.DataFrame(y_sub, columns = ['rank1','rank2','rank3'])
df_submit.to_csv('final.csv', index=False)

# %% [markdown]
# On the dataset we applied various models and got KNN as the best model.
